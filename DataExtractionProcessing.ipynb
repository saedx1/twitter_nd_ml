# %% [markdown]
# # This code is used to process the json files and extract the needed attributes to get it into the format we need

# %% [markdown]
# ### Note: we can use the Classes instead of implementing the functions
# ### Gnip

# %%
# %pylab inline
import pandas as pd
import json
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import urllib2
import numpy as np
import os
import os.path
from scipy import misc
from time import strftime,strptime
import re
import math
import pymysql
import MySQLdb
import os,sys
import gzip, json
from dateutil import parser
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def getimage(url, full_name):

    if os.path.isfile(full_name):
        return mpimg.imread(full_name)
    
    try:
        f = urllib2.urlopen(url)
    except:
        return None
    
    data = f.read()
    with open(full_name, "wb") as code:
        code.write(data)
    return mpimg.imread(full_name)


def getallimages(panda_name, column_name):
    downloaded_images = []
    for row in panda_name.loc[panda_name[column_name].notnull(),column_name]:
        for image in row:
            img = getimage(image['media_url'],image['media_url'].split('/')[-1])
            if not(img is None):
                downloaded_images.append(img)
    return downloaded_images

def klout_getId(screenname):
    url = 'http://api.klout.com/v2/identity.json/twitter?screenName={0}&key=memp3ncn4qvp6c8guzjcc8dp'.format(screenname)    
    try:
        return json.load(urllib2.urlopen(url))
    except:
        return None
    
def klout_getScore(kloutId):
    url = 'http://api.klout.com/v2/user.json/{0}/score?key=memp3ncn4qvp6c8guzjcc8dp'.format(kloutId)
    try:
        return json.load(urllib2.urlopen(url))
    except:
        return None
def extractImageUrl(cell):
    if cell is None:
        return None
    return cell[0]['media_url']

def convertDTToDB(cell):
    return strftime('%Y-%m-%d %H:%M:%S', strptime(cell,'%Y-%m-%dT%H:%M:%S.000Z'))
def getOldId(cell):
    return cell.split(':')[2]
def normalizeTweetText(text):
    if text is None or type(text) is float:
        return None
    return re.sub(r'[^\w#:@/\.\-\,]', ' ', text)

## Note that if we may put NULL for any of the attributes
## we should remove the single quotation marks from around them.
def ensureDBNull(cell):
    return 'NULL' if cell is None else ("'" + cell + "'")

def getTweetsInsertQuery(tweets):
    query = ""
    for tweet in tweets:
        temp = "REPLACE INTO tweet VALUES('{0}', '{1}', '{2}', '{3}', {4}, '{5}', {6}, {7}, {8});\n".format(tweet[0],
                                     tweet[1],
                                     tweet[2],
                                     tweet[3],
                                     ensureDBNull(tweet[4]),
                                     tweet[5],
                                     ensureDBNull(tweet[6]),
                                     ensureDBNull(tweet[7]),
                                     ensureDBNull(tweet[8]))
        
        query = "{0}{1}".format(query, temp)                         
    return query

def getUsersInsertQuery(users):
    query = ""
    for user in users:
        temp = "REPLACE INTO user VALUES('{0}', '{1}', {2}, {3}, \
          '{4}', '{5}', '{6}', {7}, '{8}');\n".format(user[0],
                                                   user[1],
                                                   ensureDBNull(user[2]),
                                                   user[3],
                                                   user[4],
                                                   user[5],
                                                   user[6],
                                                   ensureDBNull(user[7]),
                                                   user[8])

        query = "{0}{1}".format(query, temp)                
    return query

def getPlacesInsertQuery(places):
    query = ""
    for place in places:
        temp = "REPLACE INTO place VALUES ('{0}', '{1}', '{2}', '{3}');\n".format(place[0],
                                                     place[1],
                                                     place[2],
                                                     place[3])

        query = "{0}{1}".format(query, temp)
    return query


def convertNanToNone(text):
    try:
        if str(text) == 'nan':
            return None
    except:
        pass
    return text

def listToStr(cell):
    if cell is None:
        return None
    mystr = "";
    for i in cell:
        try:
            mystr = mystr + "," + str(i)
        except:
            print i
    mystr = "[{0}]".format(mystr[1:])
    return mystr
def getDBInstance():
    return MySQLdb.connect("uncg.saadmtsa.club",    # your host, usually localhost
                         "root",         # your username
                         "vJnVubg49U",  # your password
                         "geotwitter")
def extractHashTags(hashTags):
    if hashTags is None or hashTags == []:
        return None
    mylist = ''
    for hashtag in hashTags:
        mylist = mylist + ',' + hashtag['text']
    return mylist[1:]

# %%
class GnipDataProcessor(object):

    def __init__(self, i_path, collection, chunk_size=50):
        self.path = i_path
        self.chunk = []
        self.chunk_size = chunk_size
        self.collection = collection
        self.total_inserts = 0

    def all_files(self):
        for path, dirs, files in os.walk(self.path):
            for f in files:
                yield os.path.join(path, f)
    def iter_files(self):
        file_generator = self.all_files()

        for f in file_generator:
            try:
                gfile = gzip.open(f)
                for line in gfile:
                    self.process_line(line)
                gfile.close()
            except Exception as e:
                # print e
                pass
            if self.chunk != []:
                yield self.chunk
        
        

    def process_line(self, line):
        try:
            if len(self.chunk) > self.chunk_size:
                self.process_chunk()
                self.chunk = []
            if line.strip() != "":
                data = json.loads(line)
                if 'id' in data:
                    # data['postedTime_mongo'] = parser.parse(data['postedTime'])
                    self.chunk.append(line)

        except Exception as e:
            # print "error storing chunk \n"
            # print line, e.msg()
            raise

    def process_chunk(self):
        #for item in self.chunk:
        try:
            #print self.chunk
            self.total_inserts += len(self.chunk)
            # print "Inserted: %d number of docs" % self.total_inserts
        except:
            # print "issue inserting"
            pass

# %%
insrt = GnipDataProcessor("IRMA Data","", chunk_size=1000)
result = []
mygen = insrt.iter_files()
for i in mygen:
    result.append(i)

# %%
## Get the data and put it in a panda dataframe
myjson = []
# myfile = open("/home/saed/Desktop/Twitter/abc.json", 'r')
for i in result[400:500]:
    for j in i:
        try:
            myjson.append(json.loads(j))
        except:
            print j
mypanda = pd.io.json.json_normalize(myjson)

# %%
mydata = mypanda.copy()
mydata = mydata.drop_duplicates(subset = ['id'])
mydata = mydata[['id','postedTime','body','geo.coordinates', 'location.name',
                  'twitter_entities.media','twitter_lang', 'twitter_entities.hashtags','actor.id','actor.preferredUsername',
                  'actor.location.displayName','actor.verified','actor.followersCount','actor.friendsCount',
                  'actor.statusesCount','actor.postedTime', 'location.displayName',
                  'location.twitter_country_code','location.geo.coordinates']]
mydata = mydata.dropna(axis = 0, how = 'all')
mydata = mydata.loc[mydata['id'].notnull()]
mydata = mydata.reset_index(drop = True)
mydata = mydata.rename(index=str, columns={'id' : 'tweet.id', 'geo.coordinates' : 'tweet.coordinates',
                                  'postedTime' : 'tweet.created_at', 'body' : 'tweet.text', 'twitter_lang' : 'tweet.lang',
                                  'twitter_entities.media' : 'tweet.media', 'actor.id' : 'user.id',
                                  'actor.preferredUsername' : 'user.screen_name', 'actor.location.displayName' : 'user.location',
                                  'actor.verified' : 'user.verified', 'actor.followersCount': 'user.followers_count',
                                  'actor.friendsCount' : 'user.friends_count', 'actor.statusesCount' : 'user.statuses_count',
                                  'actor.postedTime' : 'user.created_at', 'twitter_entities.hashtags' : 'tweet.hashtags'})


# 4000                        None
# 4001   [26.9386463,-82.05419243]
# 4002                        None
# 4003                        None
#
#                                           location.name  \
# 0                                         Bayonet Point
# 1                                            Clearwater
# 2                                               Florida
# 3                                    Ridge Wood Heights
# 4     The NewsCenter  TBO.com, Tampa Tribune, News C...
# 5                                      Charlotte Harbor
# 6                                        Temple Terrace
# 7                                 East Lake-Orient Park
# 8                                             Tallevast
# 9                                 East Lake-Orient Park
# 10                                                Ocala
# 11                                              Florida
# 12                                              Florida
# 13                                              Florida
# 14                                East Lake-Orient Park
# 15                                               Cortez
# 16                                         Cypress Lake
# 17                                             Sarasota
# 18                                        Safety Harbor
# 19                                                 Lutz
# 20                                        St Petersburg
# 21                                         Apollo Beach
# 22                                          Tallahassee
# 23                                             Seminole
# 24                                       Temple Terrace
# 25                                               Elfers
# 26                                           Bear Creek
# 27                                          Tallahassee
# 28                                          Tallahassee
# 29                                          Tallahassee
# ...                                                 ...
# 3974                                    Egypt Lake-Leto
# 3975                                         Lido Beach
# 3976                                            Lealman
# 3977                                  Greater Northdale
# 3978                                              Tampa
# 3979                              Doak Campbell Stadium
# 3980                                        Gainesville
# 3981                                     Temple Terrace
# 3982                                              Tampa
# 3983                                     Temple Terrace
# 3984                                            Oldsmar
# 3985                                            Holiday
# 3986                                            Florida
# 3987                                        Tallahassee
# 3988                                          Fish Hawk
# 3989                                              Tampa
# 3990                                        Tallahassee
# 3991                                           Lakeland
# 3992                                          Fish Hawk
# 3993                                        Tallahassee
# 3994                                            Rubonia
# 3995                                        Tallahassee
# 3996                                              Tampa
# 3997                                          Bradenton
# 3998                                        Tallahassee
# 3999                              Doak Campbell Stadium
# 4000                                    Sugarmill Woods
# 4001                                        Punta Gorda
# 4002                                            Oldsmar
# 4003                                          Fish Hawk
#
#                                             tweet.media tweet.lang  \
# 0                                                  None         en
# 1                                                  None        und
# 2                                                  None         en
# 3                                                  None         en
# 4     http://pbs.twimg.com/ext_tw_video_thumb/916980...         en
# 5                                                  None         en
# 6                                                  None         en
# 7                                                  None         en
# 8                                                  None         en
# 9                                                  None         en
# 10                                                 None         en
# 11                                                 None         en
# 12                                                 None         en
# 13                                                 None         en
# 14                                                 None         en
# 15                                                 None         es
# 16                                                 None         en
# 17                                                 None         en
# 18                                                 None        und
# 19                                                 None         en
# 20                                                 None         fr
# 21                                                 None        und
# 22                                                 None         en
# 23                                                 None         en
# 24                                                 None         in
# 25                                                 None         en
# 26                                                 None         en
# 27                                                 None         en
# 28                                                 None         en
# 29                                                 None         en
# ...                                                 ...        ...
# 3974                                               None         en
# 3975     http://pbs.twimg.com/media/DLkn8AfWkAAdSLj.jpg         en
# 3976                                               None         de
# 3977  http://pbs.twimg.com/tweet_video_thumb/DLkoSqd...         en
# 3978                                               None         en
# 3979     http://pbs.twimg.com/media/DLkoWniX0AAzcfS.jpg        und
# 3980                                               None         en
# 3981     http://pbs.twimg.com/media/DLkohV-UIAACA54.jpg         en
# 3982                                               None         en
# 3983                                               None        und
# 3984                                               None        und
# 3985                                               None         en
# 3986                                               None         en
# 3987                                               None         en
# 3988                                               None         en
# 3989                                               None         en
# 3990                                               None         en
# 3991                                               None         en
# 3992                                               None         en
# 3993                                               None         en
# 3994                                               None         en
# 3995                                               None         en
# 3996                                               None         en
# 3997                                               None         en
# 3998                                               None         en
# 3999  http://pbs.twimg.com/ext_tw_video_thumb/916808...         en
# 4000                                               None         en
# 4001                                               None         en
# 4002                                               None         en
# 4003                                               None         en
#
#                                          tweet.hashtags
# 0                                                  None
# 1     roadtrip,throughthewindshield,palmtrees,sky,ro...
# 2                         TeamChais,TampaBay,RealEstate
# 3                                                  None
# 4                                                  None
# 5                                        relaxfulsunday
# 6                                                  None
# 7                                                  None
# 8                                GoodRiddanceJamesWoods
# 9                                                  None
# 10                                                 None
# 11                                            arthritis
# 12                                                 None
# 13                                                 None
# 14                     TWICE,SBSPopAsia,SBSPopAsiaTWICE
# 15                                                 None
# 16                                                 None
# 17                                                 None
# 18    i,must,motivate,find,select,edit,write,post,sp...
# 19                              internationalbeergarten
# 20                                                 None
# 21                                                 None
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27                                                 None
# 28                                                  Rip
# 29                                                 None
# ...                                                 ...
# 3974                                               None
# 3975                                               None
# 3976                                               None
# 3977                                               None
# 3978                                               None
# 3979                                               None
# 3980                                               None
# 3981                                MIAvsFSU,TheU,Canes
# 3982                     didntgetszechuansauce,beenugly
# 3983                                               None
# 3984                                               None
# 3985                                       empowerPasco
# 3986                                         sarasotawc
# 3987                                Canes,Noles,BeatFSU
# 3988                                               None
# 3989                                               None
# 3990                                               None
# 3991                                               None
# 3992                                               None
# 3993                                            gonoles
# 3994                                               None
# 3995                                               None
# 3996                                               None
# 3997                                              photo
# 3998                                               None
# 3999                                              Canes
# 4000                                               None
# 4001                                JerkFest,puntagorda
# 4002                         NintendoWorldChampionships
# 4003                                               None
#
# [4004 rows x 9 columns]

# %%
users = mydata[['user.id','user.screen_name','user.location','user.verified','user.followers_count','user.friends_count','user.statuses_count','user.created_at']]
users = users.drop_duplicates(subset = ['user.id'])
users['klout_score'] = [0.0] * len(users)
users
# Out:
#                  user.id user.screen_name              user.location  \
# 0     771830969934438401       SPNGIRL420        New Port Richey, FL
# 1     757948847184240646   techno_nomadic               Bushnell, FL
# 2               24633648        TeamChais             Tampa, Florida
# 3     815777993733898240    thescarybeary                      Earth
# 4               71023584        WFLAPaulM              Tampa Bay, FL
# 5             2284127615       cabaristas         Port Charlotte, FL
# 6             2876810176    JoannGuimares                  Tampa, FL
# 7             4833325693   alexis_renee18      California    Florida
# 8     773983063936294913     geribaby1947         North Sarasota, FL
# 10             123717228         _OcalaFL                  Ocala, FL
# 11            3353600338  TinaSuePatters2           Sarasota Florida
# 12              43561421    JenniCoolWhip                       None
# 13              41288447      jaybjackson           Murfreesboro, TN
# 14    915344447122153472      RobSherouse                       None
# 15              77657562     albarocuevas       Ciudadano Universal.
# 16             599549147     SBCFortMyers             Fort Myers, FL
# 17             518684416      jtalbritton         West Bradenton, FL
# 18              15939104       willchenus                  Tampa, FL
# 19              78102678         MikeKoop              Clearwater,FL
# 20              71052378    PinellasCo911   Pinellas County, Florida
# 21    763062400820051968         PoolPyro               Florida, USA
# 22              65845929       DJGHOST954                 World Wide
# 23              19511251         BOHICAR6  sundial, downtown st pete
# 24             165857230  Stovall_Special                  Tampa, FL
# 3994                13635  2015-02-25 17:15:30          0.0
# 3995                  594  2017-01-07 04:54:27          0.0
# 3996                  217  2009-04-19 15:10:46          0.0
# 4000                  695  2013-04-06 20:45:35          0.0
#
# [2092 rows x 9 columns]

# %%
places = mydata[['location.name','location.displayName','location.twitter_country_code','location.geo.coordinates']]
places = places.drop_duplicates(subset = ['location.name'])
# places['location.displayName'] = places['location.displayName'].apply(normalizeTweetText)
places.reset_index(drop = True)
places
# Out:
#                                           location.name  \
# 0                                         Bayonet Point
# 1                                            Clearwater
# 2                                               Florida
# 3                                    Ridge Wood Heights
# 4     The NewsCenter  TBO.com, Tampa Tribune, News C...
# 5                                      Charlotte Harbor
# 6                                        Temple Terrace
# 7                                 East Lake-Orient Park
# 8                                             Tallevast
# 10                                                Ocala
# 15                                               Cortez
# 16                                         Cypress Lake
# 17                                             Sarasota
# 18                                        Safety Harbor
# 19                                                 Lutz
# 20                                        St Petersburg
# 21                                         Apollo Beach
# 22                                          Tallahassee
# 23                                             Seminole
# 25                                               Elfers
# 26                                           Bear Creek
# 30                                         Holmes Beach
# 31                                            Dade City
# 32                                                 Iona
# 33                                      Treasure Island
# 34                                             Lakeland
# 36                                              Holiday
# 40                                    Gulf Gate Estates
# 41                                      Egypt Lake-Leto
# 42                                        Victory Field
# ...                                                 ...
# 3221                         GrassLands Brewing Company
# 3235                           Boca Grande Swing Bridge
# 3268                                    Sugarmill Woods
# 3328                                     Ava Restaurant
# 3338                            All Peoples Life Center
# 3355                               East Bay High School
# 3367                           Vertigo Burger And Fries
# 3371                 Dot Ice - Artisan Rolled Ice Cream
# 3373                        Florida Hospital Center Ice
# 3385                         Dulcet Restaurant   Lounge
# 3417                            The Alley at SouthShore
# 3439                       Planet Fitness - Holiday, FL
# 3452                                Hornblasters Truck
# 3456                                Bare Assets Holiday
# 3532                        Seven Springs Middle School
# 3570                                     Gulf of Mexico
# 3610                                     Gainsville, FL
# 3625                            Howard Frankland Bridge
# 3629                                      Howl-O-Scream
# 3639                           St. George Island Bridge
# 3643                                                AJA
# 3645                                       Waffle House
# 3682  David A. Straz, Jr. Center for the Performing ...
# 3687                          Seffner Christian Academy
# 3688                           Pepin Hospitality Center
# 3751                                   Dunedin Causeway
# 3864                                         Fresh Rags
# 3914      TECO Line Streetcar - Centennial Park Station
# 3944                                            Venezia
# 3975                                         Lido Beach
#
#                                    location.displayName  \
# 0                                     Bayonet Point, FL
# 1                                        Clearwater, FL
# 2                                          Florida, USA
# 3                                Ridge Wood Heights, FL
# 4     The NewsCenter (TBO.com, Tampa Tribune, News C...
# 5                                  Charlotte Harbor, FL
# 6                                    Temple Terrace, FL
# 7                             East Lake-Orient Park, FL
# 8                                         Tallevast, FL
# 10                                            Ocala, FL
# 15                                           Cortez, FL
# 16                                     Cypress Lake, FL
# 17                                         Sarasota, FL
# 18                                    Safety Harbor, FL
# 19                                             Lutz, FL
# 20                                    St Petersburg, FL
# 21                                     Apollo Beach, FL
# 22                                      Tallahassee, FL
# 23                                         Seminole, FL
# 25                                           Elfers, FL
# 26                                       Bear Creek, FL
# 30                                     Holmes Beach, FL
